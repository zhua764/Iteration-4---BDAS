# %%
import findspark
findspark.init('/home/ubuntu/spark-2.1.1-bin-hadoop2.7')
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('Iteration 4').getOrCreate()

# %%
df = spark.read.load("./cardio_train.csv", format="csv", header="true")

df.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- height: string (nullable = true)
#  |-- weight: string (nullable = true)
#  |-- ap_hi: string (nullable = true)
#  |-- ap_lo: string (nullable = true)
#  |-- cholesterol: string (nullable = true)
#  |-- gluc: string (nullable = true)
#  |-- smoke: string (nullable = true)
#  |-- alco: string (nullable = true)
#  |-- active: string (nullable = true)
#  |-- cardio: string (nullable = true)

# %%
# fix measuremnet errors
from pyspark.sql.types import (StructField,StringType,IntegerType,FloatType,StructType)

data_schema = [StructField('id',IntegerType(),True),
              StructField('age',IntegerType(),True),
              StructField('gender',IntegerType(),True),
              StructField('height',IntegerType(),True),
              StructField('weight',FloatType(),True),
              StructField('ap_hi',IntegerType(),True),
              StructField('ap_lo',IntegerType(),True),
              StructField('cholesterol',IntegerType(),True),
              StructField('gluc',IntegerType(),True),
              StructField('smoke',IntegerType(),True),
              StructField('alco',IntegerType(),True),
              StructField('active',IntegerType(),True),
              StructField('cardio',IntegerType(),True)]

final_struct = StructType(fields=data_schema)

df = spark.read.load("./cardio_train.csv", format="csv", header="true", schema=final_struct)

df.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- gender: integer (nullable = true)
#  |-- height: integer (nullable = true)
#  |-- weight: float (nullable = true)
#  |-- ap_hi: integer (nullable = true)
#  |-- ap_lo: integer (nullable = true)
#  |-- cholesterol: integer (nullable = true)
#  |-- gluc: integer (nullable = true)
#  |-- smoke: integer (nullable = true)
#  |-- alco: integer (nullable = true)
#  |-- active: integer (nullable = true)
#  |-- cardio: integer (nullable = true)

# %% [markdown]
# ###### 3.1 Select the data

# %%
# Selecting attributes
df = df.select(df.columns[1:13])
df.show()
# Out:
# +-----+------+------+------+-----+-----+-----------+----+-----+----+------+------+
# |  age|gender|height|weight|ap_hi|ap_lo|cholesterol|gluc|smoke|alco|active|cardio|
# +-----+------+------+------+-----+-----+-----------+----+-----+----+------+------+
# |18393|     2|   168|  62.0|  110|   80|          1|   1|    0|   0|     1|     0|
# |20228|     1|   156|  85.0|  140|   90|          3|   1|    0|   0|     1|     1|
# |18857|     1|   165|  64.0|  130|   70|          3|   1|    0|   0|     0|     1|
# |17623|     2|   169|  82.0|  150|  100|          1|   1|    0|   0|     1|     1|
# |17474|     1|   156|  56.0|  100|   60|          1|   1|    0|   0|     0|     0|
# |21914|     1|   151|  67.0|  120|   80|          2|   2|    0|   0|     0|     0|
# |22113|     1|   157|  93.0|  130|   80|          3|   1|    0|   0|     1|     0|
# |22584|     2|   178|  95.0|  130|   90|          3|   3|    0|   0|     1|     1|
# |17668|     1|   158|  71.0|  110|   70|          1|   1|    0|   0|     1|     0|
# |19834|     1|   164|  68.0|  110|   60|          1|   1|    0|   0|     0|     0|
# |22530|     1|   169|  80.0|  120|   80|          1|   1|    0|   0|     1|     0|
# |18815|     2|   173|  60.0|  120|   80|          1|   1|    0|   0|     1|     0|
# |14791|     2|   165|  60.0|  120|   80|          1|   1|    0|   0|     0|     0|
# |19809|     1|   158|  78.0|  110|   70|          1|   1|    0|   0|     1|     0|
# |14532|     2|   181|  95.0|  130|   90|          1|   1|    1|   1|     1|     0|
# |16782|     2|   172| 112.0|  120|   80|          1|   1|    0|   0|     0|     1|
# |21296|     1|   170|  75.0|  130|   70|          1|   1|    0|   0|     0|     0|
# |16747|     1|   158|  52.0|  110|   70|          1|   3|    0|   0|     1|     0|
# |17482|     1|   154|  68.0|  100|   70|          1|   1|    0|   0|     0|     0|
# |21755|     2|   162|  56.0|  120|   70|          1|   1|    1|   0|     1|     0|
# +-----+------+------+------+-----+-----+-----------+----+-----+----+------+------+
# only showing top 20 rows

# %%
# count number of rows
print(df.count())
# count number of columns
len(df.columns)
# Out:
# 70000
# 12

# %% [markdown]
# ###### 3.2 Clean the data

# %%
# Remove data errors
df = df.where("ap_lo > 0")
df = df.where("ap_hi > 0")
df = df.where("ap_hi > ap_lo")
df.count()
# Out:
# 68742

# %%
# Remove outliers
import pandas as pd

pdf = df.toPandas()
print("Before:", pdf.shape)
# Out:
# Before: (68742, 12)

# %%
# height
Q1 = pdf["height"].quantile(0.25)
Q3 = pdf["height"].quantile(0.75)
IQR = Q3 - Q1

pdf.drop(pdf[(pdf["height"]>Q3+1.5*IQR) | (pdf["height"]<Q1-1.5*IQR)]
    .index,inplace=True)

# %%
print("After:", pdf.shape)
# Out:
# After: (68236, 12)

# %%
# weight
Q1 = pdf["weight"].quantile(0.25)
Q3 = pdf["weight"].quantile(0.75)
IQR = Q3 - Q1

pdf.drop(pdf[(pdf["weight"]>Q3+1.5*IQR) | (pdf["weight"]<Q1-1.5*IQR)]
    .index,inplace=True)

# %%
# ap_hi
Q1 = pdf["ap_hi"].quantile(0.25)
Q3 = pdf["ap_hi"].quantile(0.75)
IQR = Q3 - Q1

pdf.drop(pdf[(pdf["ap_hi"]>Q3+1.5*IQR) | (pdf["ap_hi"]<Q1-1.5*IQR)]
    .index,inplace=True)

# %%
# ap_lo
Q1 = pdf["ap_lo"].quantile(0.25)
Q3 = pdf["ap_lo"].quantile(0.75)
IQR = Q3 - Q1

pdf.drop(pdf[(pdf["ap_lo"]>Q3+1.5*IQR) | (pdf["ap_lo"]<Q1-1.5*IQR)]
    .index,inplace=True)

# %%
print(pdf.shape)
pdf
# Out:
# (62502, 12)
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 5      21914       1     151    67.0    120     80            2     2      0
# 6      22113       1     157    93.0    130     80            3     1      0
# 7      22584       2     178    95.0    130     90            3     3      0
# 8      17668       1     158    71.0    110     70            1     1      0
# 10     22530       1     169    80.0    120     80            1     1      0
# 11     18815       2     173    60.0    120     80            1     1      0
# 12     14791       2     165    60.0    120     80            1     1      0
# 13     19809       1     158    78.0    110     70            1     1      0
# 14     14532       2     181    95.0    130     90            1     1      1
# 68715     0       1       0
# 68716     0       1       0
# 68717     0       1       1
# 68718     0       1       0
# 68719     0       1       0
# 68721     0       1       1
# 68722     1       0       0
# 68724     0       1       1
# 68725     0       1       0
# 68726     0       1       1
# 68727     1       0       1
# 68728     0       1       0
# 68729     0       1       0
# 68730     0       1       0
# 68731     0       1       1
# 68732     0       1       1
# 68733     0       1       0
# 68734     0       1       1
# 68735     0       1       1
# 68736     0       1       1
# 68737     0       1       0
# 68740     0       0       1
# 68741     0       1       0
#
# [62502 rows x 12 columns]

# %% [markdown]
# ###### 3.3 Construct the data

# %%
import numpy as np

pdf.insert(6, "blood pressure", 0)

conditionlist = [
    (pdf["ap_hi"]<120) & (pdf["ap_lo"]<80),
    (pdf["ap_hi"]>=120) & (pdf["ap_hi"]<130) & (pdf["ap_lo"]<80),
    (pdf["ap_hi"]>=130) & (pdf["ap_hi"]<140) | (pdf["ap_lo"]>=80) & (pdf["ap_lo"]<90),
    (pdf["ap_hi"]>=140) & (pdf["ap_hi"]<=180) | (pdf["ap_lo"]>=90) & (pdf["ap_lo"]<=120),
    (pdf["ap_hi"]>180) & (pdf["ap_lo"]>120)]

choicelist = [1, 2, 3, 4, 5]
pdf["blood pressure"] = np.select(conditionlist, choicelist, default=0)
pdf
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  blood pressure  \
# 0      18393       2     168    62.0    110     80               3
# 1      20228       1     156    85.0    140     90               4
# 2      18857       1     165    64.0    130     70               3
# 3      17623       2     169    82.0    150    100               4
# 5      21914       1     151    67.0    120     80               3
# 6      22113       1     157    93.0    130     80               3
# 7      22584       2     178    95.0    130     90               3
# 8      17668       1     158    71.0    110     70               1
# 10     22530       1     169    80.0    120     80               3
# 11     18815       2     173    60.0    120     80               3
# 12     14791       2     165    60.0    120     80               3
# 13     19809       1     158    78.0    110     70               1
# 14     14532       2     181    95.0    130     90               3
# 16     21296       1     170    75.0    130     70               3
# 17     16747       1     158    52.0    110     70               1
# 18     17482       1     154    68.0    100     70               1
# 19     21755       2     162    56.0    120     70               2
# 20     19778       2     163    83.0    120     80               3
# 21     21413       1     157    69.0    130     80               3
# 22     23046       1     158    90.0    145     85               3
# 24     16608       1     170    68.0    150     90               4
# 25     14453       1     153    65.0    130    100               3
# 26     19559       1     156    59.0    130     90               3
# 27     18085       1     159    78.0    120     80               3
# 28     14574       2     166    66.0    120     80               3
# 29     21057       2     169    74.0    130     70               3
# 30     18291       1     155   105.0    120     80               3
# 31     23186       1     169    71.0    140     90               4
# 32     14605       1     159    60.0    110     70               1
# 33     20652       1     160    73.0    130     85               3
# ...      ...     ...     ...     ...    ...    ...             ...
# 68708  15450       2     165    66.0    120     80               3
# 68709  20327       1     156    67.0    140     80               3
# 68710  16093       2     157    61.0    110     90               4
# 68711  20529       2     175    78.0    120     80               3
# 68712  22572       2     173   103.0    140     80               3
# 68713  20136       2     177    80.0    130     80               3
# 68714  17065       1     165    76.0    140     90               4
# 68715  22142       2     175    72.0    130     80               3
# 68716  18226       1     168    75.0    120     80               3
# 68717  21264       2     182   100.0    120     80               3
pdf.columns
# Out:
# Index(['age', 'gender', 'height', 'weight', 'blood pressure', 'cholesterol',
#        'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %% [markdown]
# ###### 3.4 Integrate various data sources

# %%
data_a = spark.read.load("./cardio_train_a.csv", format="csv", header="true")
data_b = spark.read.load("./cardio_train_b.csv", format="csv", header="true")

# %%
data_a.show()
# Out:
# +---+-----+------+------+------+-----+-----+-----------+----+-----+----+------+
# | id|  age|gender|height|weight|ap_hi|ap_lo|cholesterol|gluc|smoke|alco|active|
# +---+-----+------+------+------+-----+-----+-----------+----+-----+----+------+
# |  0|18393|     2|   168|    62|  110|   80|          1|   1|    0|   0|     1|
# |  1|20228|     1|   156|    85|  140|   90|          3|   1|    0|   0|     1|
# |  2|18857|     1|   165|    64|  130|   70|          3|   1|    0|   0|     0|
# |  3|17623|     2|   169|    82|  150|  100|          1|   1|    0|   0|     1|
# |  4|17474|     1|   156|    56|  100|   60|          1|   1|    0|   0|     0|
# |  8|21914|     1|   151|    67|  120|   80|          2|   2|    0|   0|     0|
# |  9|22113|     1|   157|    93|  130|   80|          3|   1|    0|   0|     1|
# | 12|22584|     2|   178|    95|  130|   90|          3|   3|    0|   0|     1|
# | 13|17668|     1|   158|    71|  110|   70|          1|   1|    0|   0|     1|
# | 14|19834|     1|   164|    68|  110|   60|          1|   1|    0|   0|     0|
# | 15|22530|     1|   169|    80|  120|   80|          1|   1|    0|   0|     1|
# | 16|18815|     2|   173|    60|  120|   80|          1|   1|    0|   0|     1|
# | 18|14791|     2|   165|    60|  120|   80|          1|   1|    0|   0|     0|
# | 21|19809|     1|   158|    78|  110|   70|          1|   1|    0|   0|     1|
# | 23|14532|     2|   181|    95|  130|   90|          1|   1|    1|   1|     1|
# | 24|16782|     2|   172|   112|  120|   80|          1|   1|    0|   0|     0|
# | 25|21296|     1|   170|    75|  130|   70|          1|   1|    0|   0|     0|
# | 27|16747|     1|   158|    52|  110|   70|          1|   3|    0|   0|     1|
# | 28|17482|     1|   154|    68|  100|   70|          1|   1|    0|   0|     0|
# | 29|21755|     2|   162|    56|  120|   70|          1|   1|    1|   0|     1|
# +---+-----+------+------+------+-----+-----+-----------+----+-----+----+------+
# only showing top 20 rows

# %%
data_b.show()
# Out:
# +---+------+
# | id|cardio|
# +---+------+
# |  0|     0|
# |  1|     1|
# |  2|     1|
# |  3|     1|
# |  4|     0|
# |  8|     0|
# |  9|     0|
# | 12|     1|
# | 13|     0|
# | 14|     0|
# | 15|     0|
# | 16|     0|
# | 18|     0|
# | 21|     0|
# | 23|     0|
# | 24|     1|
# | 25|     0|
# | 27|     0|
# | 28|     0|
# | 29|     0|
# +---+------+
# only showing top 20 rows

# %%
df_inner = data_a.join(data_b, on=['id'], how='inner')
df_inner.show()
# Out:
# +---+-----+------+------+------+-----+-----+-----------+----+-----+----+------+------+
# | id|  age|gender|height|weight|ap_hi|ap_lo|cholesterol|gluc|smoke|alco|active|cardio|
# +---+-----+------+------+------+-----+-----+-----------+----+-----+----+------+------+
# |  0|18393|     2|   168|    62|  110|   80|          1|   1|    0|   0|     1|     0|
# |  1|20228|     1|   156|    85|  140|   90|          3|   1|    0|   0|     1|     1|
# |  2|18857|     1|   165|    64|  130|   70|          3|   1|    0|   0|     0|     1|
# |  3|17623|     2|   169|    82|  150|  100|          1|   1|    0|   0|     1|     1|
# |  4|17474|     1|   156|    56|  100|   60|          1|   1|    0|   0|     0|     0|
# |  8|21914|     1|   151|    67|  120|   80|          2|   2|    0|   0|     0|     0|
# |  9|22113|     1|   157|    93|  130|   80|          3|   1|    0|   0|     1|     0|
# | 12|22584|     2|   178|    95|  130|   90|          3|   3|    0|   0|     1|     1|
# | 13|17668|     1|   158|    71|  110|   70|          1|   1|    0|   0|     1|     0|
# | 14|19834|     1|   164|    68|  110|   60|          1|   1|    0|   0|     0|     0|
# | 15|22530|     1|   169|    80|  120|   80|          1|   1|    0|   0|     1|     0|
# | 16|18815|     2|   173|    60|  120|   80|          1|   1|    0|   0|     1|     0|
# | 18|14791|     2|   165|    60|  120|   80|          1|   1|    0|   0|     0|     0|
# | 21|19809|     1|   158|    78|  110|   70|          1|   1|    0|   0|     1|     0|
# | 23|14532|     2|   181|    95|  130|   90|          1|   1|    1|   1|     1|     0|
# | 24|16782|     2|   172|   112|  120|   80|          1|   1|    0|   0|     0|     1|
# | 25|21296|     1|   170|    75|  130|   70|          1|   1|    0|   0|     0|     0|
# | 27|16747|     1|   158|    52|  110|   70|          1|   3|    0|   0|     1|     0|
# | 28|17482|     1|   154|    68|  100|   70|          1|   1|    0|   0|     0|     0|
# | 29|21755|     2|   162|    56|  120|   70|          1|   1|    1|   0|     1|     0|
# +---+-----+------+------+------+-----+-----+-----------+----+-----+----+------+------+
# only showing top 20 rows

# %% [markdown]
# ###### 3.5 Format the data

# %%
pdf["age"] = (pdf["age"] / 365).round().astype("int")
pdf
# Out:
#        age  gender  height  weight  blood pressure  cholesterol  gluc  smoke  \
# 0       50       2     168    62.0               3            1     1      0
# 1       55       1     156    85.0               4            3     1      0
# 2       52       1     165    64.0               3            3     1      0
# 3       48       2     169    82.0               4            1     1      0
# 5       60       1     151    67.0               3            2     2      0
# 6       61       1     157    93.0               3            3     1      0
# 7       62       2     178    95.0               3            3     3      0
# 8       48       1     158    71.0               1            1     1      0
# 10      62       1     169    80.0               3            1     1      0
# 11      52       2     173    60.0               3            1     1      0
# 12      41       2     165    60.0               3            1     1      0
# 13      54       1     158    78.0               1            1     1      0
# 14      40       2     181    95.0               3            1     1      1
# 16      58       1     170    75.0               3            1     1      0
# 17      46       1     158    52.0               1            1     3      0
# 18      48       1     154    68.0               1            1     1      0
# 19      60       2     162    56.0               2            1     1      1
# 20      54       2     163    83.0               3            1     1      0
# 21      59       1     157    69.0               3            1     1      0
# 22      63       1     158    90.0               3            2     2      0
# 24      46       1     170    68.0               4            3     1      0
# 25      40       1     153    65.0               3            2     1      0
# 26      54       1     156    59.0               3            1     1      0
# 27      50       1     159    78.0               3            1     1      0
# 28      40       2     166    66.0               3            1     1      0
# 29      58       2     169    74.0               3            1     3      0
# 30      50       1     155   105.0               3            3     1      0
# 31      64       1     169    71.0               4            3     1      0
# 32      40       1     159    60.0               1            1     1      0
# 33      57       1     160    73.0               3            1     1      0
# ...    ...     ...     ...     ...             ...          ...   ...    ...
# 68708   42       2     165    66.0               3            1     1      0
# 68709   56       1     156    67.0               3            2     1      0
# 68710   44       2     157    61.0               4            1     1      0
# 68711   56       2     175    78.0               3            1     1      0
# 68712   62       2     173   103.0               3            3     1      1
# 68713   55       2     177    80.0               3            1     1      0
# 68714   47       1     165    76.0               4            1     1      0
# 68715   61       2     175    72.0               3            1     1      0
# 68716   50       1     168    75.0               3            1     1      0
# 68717   58       2     182   100.0               3            1     1      0
# 68718   59       1     163    65.0               3            2     2      0
# 68719   46       1     168    75.0               2            1     1      0
# 68721   61       1     163    74.0               4            2     2      0
# 68722   49       2     167    69.0               3            1     1      0
# 68724   52       1     153    86.0               3            1     2      0
# 68725   54       1     165    72.0               3            1     1      0
# 68726   49       2     168    80.0               3            1     1      0
# 68727   50       1     156   102.0               3            1     1      0
# 68728   50       2     180    78.0               3            1     1      0
# 68729   52       1     151    49.0               3            1     1      0
# 68730   60       1     160    59.0               1            1     1      0
# 68731   58       1     157    83.0               2            1     1      0
# 68732   41       1     168    72.0               1            1     1      0
# 68733   56       1     159    72.0               3            2     2      0
# 68734   51       1     161    56.0               4            1     1      0
# 68735   54       1     172    70.0               3            1     1      0
# 68736   58       1     165    80.0               3            1     1      0
# 68737   53       2     168    76.0               3            1     1      1
# 68740   61       1     163    72.0               3            1     2      0
# 68741   56       1     170    72.0               3            2     1      0
#
#        alco  active  cardio
# 0         0       1       0
# 1         0       1       1
# 2         0       0       1
# 3         0       1       1
# 5         0       0       0
# 6         0       1       0
# 7         0       1       1
# 8         0       1       0
# 10        0       1       0
# 11        0       1       0
# 12        0       0       0
# 13        0       1       0
# 14        1       1       0
# 16        0       0       0
# 17        0       1       0
# 18        0       0       0
# 19        0       1       0
# 20        0       1       0
# 21        0       1       0
# 22        0       1       1
# 24        0       1       1
# 25        0       1       0
# 26        0       1       0
# 27        0       1       0
# 28        0       1       0
# 29        0       0       0
# 30        0       1       1
# 31        0       1       1
# 32        0       1       0
# 33        0       0       1
# ...     ...     ...     ...
# 68708     0       0       0
# 68709     0       0       0
# 68710     0       1       0
# 68711     0       0       0
# 68712     1       0       1
# 68713     0       1       0
# 68714     0       1       1
# 68715     0       1       0
# 68716     0       1       0
# 68717     0       1       1
# 68718     0       1       0
# 68719     0       1       0
# 68721     0       1       1
# 68722     1       0       0
# 68724     0       1       1
# 68725     0       1       0
# 68726     0       1       1
# 68727     1       0       1
# 68728     0       1       0
# 68729     0       1       0
# 68730     0       1       0
# 68731     0       1       1
# 68732     0       1       1
# 68733     0       1       0
# 68734     0       1       1
# 68735     0       1       1
# 68736     0       1       1
# 68737     0       1       0
# 68740     0       0       1
# 68741     0       1       0
#
# [62502 rows x 11 columns]

# %%
pdf.to_csv("new_train.csv", index=False)
